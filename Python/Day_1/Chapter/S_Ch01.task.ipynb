# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```인터프리트 방식에 대해 설명하고 2개 이상의 장점을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1. 개발 과정에서 즉시 결과를 확인할 수 있어 개발 속도가 빠릅니다.
# 2. 메모리 사용이 효율적입니다. (전체 프로그램을 한번에 로드할 필요가 없기 때문.)

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```동적 타입 방식의 장점과 단점을 간략히 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 장점 : 코드 작성 속도가 빠르고 유연함
# 단점 : 실행 속도가 정적 타입의 방식보다 느릴 수 있음

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```Python으로 정적타입 방식의 코드를 작성할 수 있는 방법을 구글링을 통해 검색 후 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1. 타입 힌팅 : Python 3.5부터 도입된 기능으로, 변수, 함수 매개변수, 반환값 등에 타입을 명시할 수 있음.
#
# 2. 타입 검사 도구 : mypy, Pyright, Pyre 등의 도구를 사용하여 코드를 실행하기 전에 타입 오류를 검출할 수 있음.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```프로세스와 스레드의 차이점을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 프로세스 : 실행 중인 프로그램의 인스턴스로, 독릭접인 메모리 공간을 가진다.
#
# 스레드 : 프로세스 내에서 실행되는 작업의 단위로, 같은 프로세스의 스레드들은 메모리 공간을 공유함.
#
# 차이점 = 프로세스는 독립적인 메모리 공간을 가지지만 스레드는 메모리를 공유함.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```Python 2버전대와 3버전대의 차이를 성명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# Python 2: 문자열이 ASCII 기반이며, 유니코드를 처리하기 위해서는 명시적으로 u 접두사를 사용해야 함
#
# Python 3: 모든 문자열이 기본적으로 유니코드(UTF-8)을 지원함.

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:80%">[문제6]<br><br></span>
# ```Python에서 메모리 관리는 어떻게 이루어지는지 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# Python의 메모리 관리는 참조 카운팅과 가비지 컬렉션을 통해 자동으로 이루어지며, 개발자가 직접 메모리를 할당하거나 해제할 필요가 없습니다.
