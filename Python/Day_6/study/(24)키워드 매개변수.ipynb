# %%
# (기본 매개변수, 가변 매개변수)

def oz(n=3, *values):
    for i in range(n):
        for value in values:
            print(value)
        print()

oz("기본 매개변수 다음에", "가변 매개변수를", "넣을 수 있을까요?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a02628fda68d> in <cell line: 0>()
#       7         print()
#       8
# ----> 9 oz("기본 매개변수 다음에", "가변 매개변수를", "넣을 수 있을까요?")
#
# <ipython-input-3-a02628fda68d> in oz(n, *values)
#       2
#       3 def oz(n=3, *values):
# ----> 4     for i in range(n):
#       5         for value in values:
#       6             print(value)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
# (가변 매개변수, 기본 매개변수)

def oz(*values, n=3):
    for i in range(n):
        for value in values:
            print(value)
        print()

oz("가변 매개변수 다음에", "기본 매개변수를", "넣을 수 있을까요?", 10)
# Out:
# 가변 매개변수 다음에
# 기본 매개변수를
# 넣을 수 있을까요?
# 10
#
# 가변 매개변수 다음에
# 기본 매개변수를
# 넣을 수 있을까요?
# 10
#
# 가변 매개변수 다음에
# 기본 매개변수를
# 넣을 수 있을까요?
# 10

# %%
# end = \n    <= 키워드 매개변수
list = ["안", "녕", "하", "세", "요"]
for i in list:
    print(i)
# Out:
# 안
# 녕
# 하
# 세
# 요

# %%
list = ["안", "녕", "하", "세", "요"]
for i in list:
    print(i, end="")
# Out:
# 안녕하세요

# %%
# 직육면체를 부피를 구하는 코드를 작성해보자! : 가로 : x, 세로 : y, 높이 : h
def oz(x, y=20, h=10):
    print(x * y * h)

# x 식별자에 매개변수 10을 넣은 경우
(oz(10))
# x 식별자에 10을 넣고 y=10이라는 키워드 매개변수를 이용한 경우
(oz(10, y=10))
# 모든 매개변수를 키워드 매개변수로 넣은 경우
(oz(x=5, y=5, h=5))
# Out:
# 2000
# 1000
# 125

# %% [markdown]
# ### 키워드 매개변수를 사용하는 이유에 대해 설명해주세요 :
#
# 1. 매개변수의 순서에 상관없이 함수를 호출할 때 값을 전달할 수 있다.
#
# ### 키워드 매개변수를 사용하기 위한 문법에 대해 설명해주세요 :
#
# 1. 매개변수 이름 뒤에 = 기호를 사용하여 사용
